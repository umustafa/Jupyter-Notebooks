# %%
import pandas as pd
from pandas_datareader import data
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Use the `plot()` Method to Render a Line Chart

# %%
bb = data.DataReader(name="BB", data_source="yahoo", start="2007-01-01", end="2020-12-31")
bb.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668

# %%
bb.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3525 entries, 2007-01-03 to 2020-12-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       3525 non-null   float64
#  1   Low        3525 non-null   float64
#  2   Open       3525 non-null   float64
#  3   Close      3525 non-null   float64
#  4   Volume     3525 non-null   float64
#  5   Adj Close  3525 non-null   float64
# dtypes: float64(6)
# memory usage: 192.8 KB

# %%
bb.plot(y="High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb["High"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb[["High", "Low"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bb[["High", "Close"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Modifying Plot Aesthetics with `matplotlib` Templates

# %%
bb
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24   7.240000   7.050000   7.120000   7.060000   6088300.0   7.060000
# 2020-12-28   7.130000   6.850000   7.100000   6.880000   9820100.0   6.880000
# 2020-12-29   7.000000   6.680000   6.980000   6.770000  11284200.0   6.770000
# 2020-12-30   6.810000   6.600000   6.790000   6.670000   9434900.0   6.670000
# 2020-12-31   6.800000   6.630000   6.680000   6.630000   7530600.0   6.630000
#
# [3525 rows x 6 columns]

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("dark_background")
bb.plot(y="High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("ggplot")
bb.plot(y="High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Creating Bar Graphs to Show Counts

# %%
bb
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24   7.240000   7.050000   7.120000   7.060000   6088300.0   7.060000
# 2020-12-28   7.130000   6.850000   7.100000   6.880000   9820100.0   6.880000
# 2020-12-29   7.000000   6.680000   6.980000   6.770000  11284200.0   6.770000
# 2020-12-30   6.810000   6.600000   6.790000   6.670000   9434900.0   6.670000
# 2020-12-31   6.800000   6.630000   6.680000   6.630000   7530600.0   6.630000
#
# [3525 rows x 6 columns]

# %%
def rank_perf(stock_price):
    if stock_price <= 10:
        return "Poor"
    elif stock_price <= 50:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
bb["Close"].apply(rank_perf).value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
bb["Close"].apply(rank_perf).value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Creating Pie Charts to Represent Proportions

# %%
bb.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2007-01-03  44.026669  41.703335  43.086666  42.849998  34739100.0  42.849998
# 2007-01-04  46.316666  42.423332  42.953335  46.189999  46007700.0  46.189999
# 2007-01-05  47.306667  45.166668  45.500000  47.099998  41453400.0  47.099998
# 2007-01-08  48.410000  46.606667  47.283333  47.386665  38547300.0  47.386665
# 2007-01-09  47.666668  43.263332  47.570000  43.666668  74142000.0  43.666668

# %%
bb["Close"].mean()
# Out:
# 29.452764073094578

# %%
def rank_perf(stock_price):
    if stock_price >= 29.452764073094578:
        return "Above Average"
    else:
        return "Below Average"

# %%
plt.style.use("dark_background")

# %%
bb["Close"].apply(rank_perf).value_counts().plot(kind="pie", legend=True)
# Out:
# <AxesSubplot:ylabel='Close'>
